# %%
print ("jupyter is working")
# Out:
# jupyter is working

# %%
pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2-binary in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (2.9.12)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (2.32.5)
# Requirement already satisfied: pandas in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (2.3.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from requests) (3.17)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from requests) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from requests) (2026.5.20)
# Requirement already satisfied: numpy>=1.22.4 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jeffrey/Library/Python/3.9/lib/python/site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os
load_dotenv()
API_KEY = os.getenv("API_KEY")
API_HOST = "aerodatabox.p.rapidapi.com"
HEADERS = {
    "x-rapidapi-key": API_KEY,
    "x-rapidapi-host": API_HOST
}
DB_CONFIG = {
    "host": "localhost",
    "port": "5432",
    "database": "air_tracker",
    "user": "postgres",
    "password": os.getenv("DB_PASSWORD")
}
print("Config ready!")
# Out:
# Config ready!

# %%
import requests
import pandas as pd
import psycopg2
import json
from datetime import datetime, timedelta
print("All libraries imported successfully!")
# Out:
# /Users/jeffrey/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# All libraries imported successfully!

# %%
def get_connection():
    conn = psycopg2.connect(
        host=DB_CONFIG["host"],
        port=DB_CONFIG["port"],
        database=DB_CONFIG["database"],
        user=DB_CONFIG["user"],
        password=DB_CONFIG["password"]
    )
    return conn

# Test the connection
try:
    conn = get_connection()
    print("Connected to PostgreSQL successfully!")
    conn.close()
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Connected to PostgreSQL successfully!

# %%
import time
AIRPORT_CODES = [
    "DXB", "SIN", "LHR", "JFK", "SYD", "DOH", "BKK", "CDG",
    "MAA", "DEL", "BOM", "BLR", "HYD", "CCU", "COK"
]
def fetch_airport(iata_code):
    url = f"https://{API_HOST}/airports/iata/{iata_code}"
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error fetching {iata_code}: {e}")
        return None
airports_data = []
for code in AIRPORT_CODES:
    print(f"Fetching {code}...")
    data = None
    attempts = 0
    while data is None and attempts < 3:
        data = fetch_airport(code)
        if data is None:
            time.sleep(3)
        attempts += 1
    if data:
        airports_data.append(data)
    time.sleep(2)
print(f"\nSuccessfully fetched {len(airports_data)} airports!")
# Out:
# Fetching DXB...
# Fetching SIN...
# Fetching LHR...
# Fetching JFK...
# Fetching SYD...
# Fetching DOH...
# Fetching BKK...
# Fetching CDG...
# Fetching MAA...
# Fetching DEL...
# Fetching BOM...
# Fetching BLR...
# Fetching HYD...
# Fetching CCU...
# Fetching COK...
#
# Successfully fetched 15 airports!

# %%
print(json.dumps(airports_data[0], indent=2))
# Out:
# {
#   "icao": "OMDB",
#   "iata": "DXB",
#   "shortName": "Dubai",
#   "fullName": "Dubai",
#   "municipalityName": "Dubai",
#   "location": {
#     "lat": 25.252798,
#     "lon": 55.3644
#   },
#   "elevation": {
#     "meter": 18.9,
#     "km": 0.02,
#     "mile": 0.01,
#     "nm": 0.01,
#     "feet": 62.0
#   },
#   "country": {
#     "code": "AE",
#     "name": "United Arab Emirates"
#   },
#   "continent": {
#     "code": "AS",
#     "name": "Asia"
#   },
#   "timeZone": "Asia/Dubai",
#   "urls": {
#     "webSite": "http://www.dubaiairports.ae/",
#     "wikipedia": "https://en.wikipedia.org/wiki/Dubai_International_Airport",
#     "twitter": "https://x.com/DubaiAirports",
#     "flightRadar": "https://www.flightradar24.com/25.25,55.36/14",
#     "googleMaps": "https://www.google.com/maps/@25.252799,55.364398,14z"
#   }
# }

# %%
# Insert airport data into PostgreSQL
def insert_airports(airports):
    conn = get_connection()
    cursor = conn.cursor()
    
    for airport in airports:
        try:
            cursor.execute("""
                INSERT INTO airport 
                (icao_code, iata_code, name, city, country, continent, latitude, longitude, timezone)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
                ON CONFLICT (iata_code) DO NOTHING
            """, (
                airport.get("icao"),
                airport.get("iata"),
                airport.get("fullName"),
                airport.get("municipalityName"),
                airport.get("country", {}).get("name"),
                airport.get("continent", {}).get("name"),
                airport.get("location", {}).get("lat"),
                airport.get("location", {}).get("lon"),
                airport.get("timeZone")
            ))
        except Exception as e:
            print(f"Error inserting {airport.get('iata')}: {e}")
    
    conn.commit()
    cursor.close()
    conn.close()
    print(f"Inserted {len(airports)} airports successfully!")

insert_airports(airports_data)
# Out:
# Inserted 15 airports successfully!

# %%
def fetch_flights(iata_code, date):
    url = f"https://{API_HOST}/flights/airports/iata/{iata_code}"
    params = {
        "fromLocal": f"{date}T00:00",
        "toLocal": f"{date}T23:59",
        "withLeg": "true",
        "direction": "Both",
        "withCancelled": "true",
        "withCodeshared": "false",
        "withCargo": "false",
        "withPrivate": "false"
    }
    try:
        response = requests.get(url, headers=HEADERS, params=params)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error fetching flights for {iata_code}: {e}")
        return None

# Test with MAA for yesterday
yesterday = (datetime.now() - timedelta(days=1)).strftime("%Y-%m-%d")
print(f"Fetching flights for MAA on {yesterday}...")
test_flights = fetch_flights("MAA", yesterday)
print(json.dumps(test_flights, indent=2))
# Out:
# Fetching flights for MAA on 2026-06-13...
# {
#   "departures": [
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:05Z",
#           "local": "2026-06-14 13:35+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:10Z",
#           "local": "2026-06-14 15:40+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 09:46Z",
#           "local": "2026-06-14 15:16+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "5",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "QP 3046",
#       "status": "Departed",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Boeing 737"
#       },
#       "airline": {
#         "name": "Starlight Airline",
#         "iata": "QP",
#         "icao": "SLT"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:20Z",
#           "local": "2026-06-14 13:50+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "name": "Durgapur"
#         },
#         "quality": []
#       },
#       "number": "6E 981",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:25Z",
#           "local": "2026-06-14 13:55+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VGHS",
#           "iata": "DAC",
#           "name": "Dhaka",
#           "countryCode": "bd",
#           "timeZone": "Asia/Dhaka"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 11:05Z",
#           "local": "2026-06-14 17:05+06:00"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "BS 206",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Boeing 737-800"
#       },
#       "airline": {
#         "name": "US-Bangla",
#         "iata": "BS",
#         "icao": "UBG"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:30Z",
#           "local": "2026-06-14 14:00+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VIDP",
#           "iata": "DEL",
#           "name": "New Delhi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:49Z",
#           "local": "2026-06-14 16:19+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 10:49Z",
#           "local": "2026-06-14 16:19+05:30"
#         },
#         "terminal": "3",
#         "baggageBelt": "03",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "AI 2468",
#       "callSign": "AIC2AT",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-EXV",
#         "modeS": "800BFA",
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "Air India",
#         "iata": "AI",
#         "icao": "AIC"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:40Z",
#           "local": "2026-06-14 14:10+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOKN",
#           "iata": "CNN",
#           "name": "Kannur",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:20Z",
#           "local": "2026-06-14 15:50+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7335",
#       "callSign": "IGO7335",
#       "status": "Unknown",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-IYU",
#         "modeS": "800DB2",
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:40Z",
#           "local": "2026-06-14 14:10+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "name": "Tutikorin"
#         },
#         "quality": []
#       },
#       "number": "6E 7179",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:45Z",
#           "local": "2026-06-14 14:15+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOCB",
#           "iata": "CJB",
#           "name": "Coimbatore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 09:50Z",
#           "local": "2026-06-14 15:20+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 881",
#       "callSign": "IGO881",
#       "status": "Unknown",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-IXA",
#         "modeS": "80169C",
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:45Z",
#           "local": "2026-06-14 14:15+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOSM",
#           "iata": "SXV",
#           "name": "Salem",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 09:55Z",
#           "local": "2026-06-14 15:25+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7678",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:50Z",
#           "local": "2026-06-14 14:20+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "WSSS",
#           "iata": "SIN",
#           "name": "Singapore",
#           "countryCode": "sg",
#           "timeZone": "Asia/Singapore"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:20Z",
#           "local": "2026-06-14 21:20+08:00"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 13:20Z",
#           "local": "2026-06-14 21:20+08:00"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 1003",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 08:55Z",
#           "local": "2026-06-14 14:25+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOMD",
#           "iata": "IXM",
#           "name": "Madurai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:20Z",
#           "local": "2026-06-14 15:50+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7515",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:00Z",
#           "local": "2026-06-14 14:30+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOCP",
#           "iata": "CDP",
#           "name": "Kuddapakh",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:00Z",
#           "local": "2026-06-14 15:30+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7282",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:00Z",
#           "local": "2026-06-14 14:30+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VIDP",
#           "iata": "DEL",
#           "name": "New Delhi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:00Z",
#           "local": "2026-06-14 17:30+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 12:00Z",
#           "local": "2026-06-14 17:30+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "03",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 948",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:05Z",
#           "local": "2026-06-14 14:35+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOBL",
#           "iata": "BLR",
#           "name": "Bangalore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:10Z",
#           "local": "2026-06-14 15:40+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 10:10Z",
#           "local": "2026-06-14 15:40+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "3",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 6209",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-IBZ",
#         "modeS": "8015E7",
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:15Z",
#           "local": "2026-06-14 14:45+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 11:10Z",
#           "local": "2026-06-14 16:40+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 11:10Z",
#           "local": "2026-06-14 16:40+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "4",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 5371",
#       "status": "Departed",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:20Z",
#           "local": "2026-06-14 14:50+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOTV",
#           "iata": "TRV",
#           "name": "Trivandrum",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:40Z",
#           "local": "2026-06-14 16:10+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6216",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:25Z",
#           "local": "2026-06-14 14:55+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VCBI",
#           "iata": "CMB",
#           "name": "Colombo",
#           "countryCode": "lk",
#           "timeZone": "Asia/Colombo"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:45Z",
#           "local": "2026-06-14 16:15+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 1179",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:25Z",
#           "local": "2026-06-14 14:55+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VEGT",
#           "iata": "GAU",
#           "name": "Guwahati",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:30Z",
#           "local": "2026-06-14 18:00+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "IX 1354",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Boeing 737"
#       },
#       "airline": {
#         "name": "Air India Express",
#         "iata": "IX",
#         "icao": "AXB"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:35Z",
#           "local": "2026-06-14 15:05+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOTR",
#           "iata": "TRZ",
#           "name": "Tiruchirappally",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 10:45Z",
#           "local": "2026-06-14 16:15+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7199",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 09:55Z",
#           "local": "2026-06-14 15:25+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VEBD",
#           "iata": "IXB",
#           "name": "Siliguri",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:30Z",
#           "local": "2026-06-14 18:00+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "IX 2408",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Boeing 737-800"
#       },
#       "airline": {
#         "name": "Air India Express",
#         "iata": "IX",
#         "icao": "AXB"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:00Z",
#           "local": "2026-06-14 15:30+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "OOMS",
#           "iata": "MCT",
#           "name": "Muscat",
#           "countryCode": "om",
#           "timeZone": "Asia/Muscat"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:50Z",
#           "local": "2026-06-14 17:50+04:00"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "WY 254",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Boeing 737-800"
#       },
#       "airline": {
#         "name": "Oman Air",
#         "iata": "WY",
#         "icao": "OMA"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:15Z",
#           "local": "2026-06-14 15:45+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VICG",
#           "iata": "IXC",
#           "name": "Chandigarh",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:25Z",
#           "local": "2026-06-14 18:55+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6005",
#       "status": "Unknown",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:20Z",
#           "local": "2026-06-14 15:50+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOCL",
#           "iata": "CCJ",
#           "name": "Calicut",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:05Z",
#           "local": "2026-06-14 17:35+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7197",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:20Z",
#           "local": "2026-06-14 15:50+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VEGT",
#           "iata": "GAU",
#           "name": "Guwahati",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:15Z",
#           "local": "2026-06-14 18:45+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6011",
#       "callSign": "IGO6011",
#       "status": "Unknown",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-ISW",
#         "modeS": "801458",
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:25Z",
#           "local": "2026-06-14 15:55+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VCBI",
#           "iata": "CMB",
#           "name": "Colombo",
#           "countryCode": "lk",
#           "timeZone": "Asia/Colombo"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 11:50Z",
#           "local": "2026-06-14 17:20+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "UL 128",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "SriLankan",
#         "iata": "UL",
#         "icao": "ALK"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:30Z",
#           "local": "2026-06-14 16:00+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:55Z",
#           "local": "2026-06-14 18:25+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 12:20Z",
#           "local": "2026-06-14 17:50+05:30"
#         },
#         "terminal": "2",
#         "baggageBelt": "13",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "AI 2740",
#       "status": "Departed",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "Air India",
#         "iata": "AI",
#         "icao": "AIC"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:40Z",
#           "local": "2026-06-14 16:10+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOHS",
#           "iata": "HYD",
#           "name": "Hyderabad",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 11:55Z",
#           "local": "2026-06-14 17:25+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6158",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:40Z",
#           "local": "2026-06-14 16:10+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOMD",
#           "iata": "IXM",
#           "name": "Madurai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:05Z",
#           "local": "2026-06-14 17:35+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7301",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 10:45Z",
#           "local": "2026-06-14 16:15+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOBL",
#           "iata": "BLR",
#           "name": "Bangalore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 11:50Z",
#           "local": "2026-06-14 17:20+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 11:50Z",
#           "local": "2026-06-14 17:20+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "4",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 847",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-IMR",
#         "modeS": "8014DF",
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:00Z",
#           "local": "2026-06-14 16:30+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOVZ",
#           "iata": "VTZ",
#           "name": "Visakhapatnam",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:25Z",
#           "local": "2026-06-14 17:55+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 2698",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:05Z",
#           "local": "2026-06-14 16:35+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VAPO",
#           "iata": "PNQ",
#           "name": "Pune",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:45Z",
#           "local": "2026-06-14 18:15+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 183",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:10Z",
#           "local": "2026-06-14 16:40+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:10Z",
#           "local": "2026-06-14 18:40+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 12:56Z",
#           "local": "2026-06-14 18:26+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "2",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 5104",
#       "status": "Departed",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:15Z",
#           "local": "2026-06-14 16:45+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VIDP",
#           "iata": "DEL",
#           "name": "New Delhi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:10Z",
#           "local": "2026-06-14 19:40+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 14:10Z",
#           "local": "2026-06-14 19:40+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "08",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 698",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:30Z",
#           "local": "2026-06-14 17:00+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VERC",
#           "iata": "IXR",
#           "name": "Ranchi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:40Z",
#           "local": "2026-06-14 19:10+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6113",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:45Z",
#           "local": "2026-06-14 17:15+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VEBS",
#           "iata": "BBI",
#           "name": "Bhubaneswar",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:35Z",
#           "local": "2026-06-14 19:05+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 143",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 11:50Z",
#           "local": "2026-06-14 17:20+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOMY",
#           "iata": "MYQ",
#           "name": "Mysore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:20Z",
#           "local": "2026-06-14 18:50+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7603",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:10Z",
#           "local": "2026-06-14 17:40+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOGO",
#           "iata": "GOI",
#           "name": "Vasco da Gama",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:40Z",
#           "local": "2026-06-14 19:10+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 588",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:15Z",
#           "local": "2026-06-14 17:45+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOCI",
#           "iata": "COK",
#           "name": "Kochi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:30Z",
#           "local": "2026-06-14 19:00+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 597",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:20Z",
#           "local": "2026-06-14 17:50+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VAAH",
#           "iata": "AMD",
#           "name": "Ahmedabad",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:35Z",
#           "local": "2026-06-14 20:05+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 848",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:30Z",
#           "local": "2026-06-14 18:00+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:50Z",
#           "local": "2026-06-14 20:20+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 14:01Z",
#           "local": "2026-06-14 19:31+05:30"
#         },
#         "terminal": "2",
#         "baggageBelt": "13",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "AI 640",
#       "status": "Departed",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A321"
#       },
#       "airline": {
#         "name": "Air India",
#         "iata": "AI",
#         "icao": "AIC"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:35Z",
#           "local": "2026-06-14 18:05+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VECC",
#           "iata": "CCU",
#           "name": "Kolkata",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 15:05Z",
#           "local": "2026-06-14 20:35+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 606",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:35Z",
#           "local": "2026-06-14 18:05+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOMD",
#           "iata": "IXM",
#           "name": "Madurai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:05Z",
#           "local": "2026-06-14 19:35+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7181",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:45Z",
#           "local": "2026-06-14 18:15+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VAID",
#           "iata": "IDR",
#           "name": "Indore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 15:00Z",
#           "local": "2026-06-14 20:30+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 489",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:45Z",
#           "local": "2026-06-14 18:15+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "name": "Tutikorin"
#         },
#         "quality": []
#       },
#       "number": "6E 7605",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:45Z",
#           "local": "2026-06-14 18:15+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:45Z",
#           "local": "2026-06-14 20:15+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 14:19Z",
#           "local": "2026-06-14 19:49+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "1",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 5367",
#       "status": "Departed",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:50Z",
#           "local": "2026-06-14 18:20+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOCB",
#           "iata": "CJB",
#           "name": "Coimbatore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:55Z",
#           "local": "2026-06-14 19:25+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 726",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:50Z",
#           "local": "2026-06-14 18:20+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOHS",
#           "iata": "HYD",
#           "name": "Hyderabad",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:05Z",
#           "local": "2026-06-14 19:35+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 562",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 12:55Z",
#           "local": "2026-06-14 18:25+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOTR",
#           "iata": "TRZ",
#           "name": "Tiruchirappally",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:05Z",
#           "local": "2026-06-14 19:35+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7238",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 13:00Z",
#           "local": "2026-06-14 18:30+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOBZ",
#           "iata": "VGA",
#           "name": "Vidzhayavada",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:25Z",
#           "local": "2026-06-14 19:55+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7291",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 13:25Z",
#           "local": "2026-06-14 18:55+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VOBL",
#           "iata": "BLR",
#           "name": "Bangalore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:40Z",
#           "local": "2026-06-14 20:10+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 14:30Z",
#           "local": "2026-06-14 20:00+05:30"
#         },
#         "terminal": "2",
#         "baggageBelt": "7A",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "IX 2507",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-BWC",
#         "modeS": "801699",
#         "model": "Boeing 737"
#       },
#       "airline": {
#         "name": "Air India Express",
#         "iata": "IX",
#         "icao": "AXB"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 13:30Z",
#           "local": "2026-06-14 19:00+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VIJP",
#           "iata": "JAI",
#           "name": "Jaipur",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 16:00Z",
#           "local": "2026-06-14 21:30+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6381",
#       "status": "Unknown",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 13:30Z",
#           "local": "2026-06-14 19:00+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "airport": {
#           "icao": "VIDP",
#           "iata": "DEL",
#           "name": "New Delhi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 15:53Z",
#           "local": "2026-06-14 21:23+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 15:53Z",
#           "local": "2026-06-14 21:23+05:30"
#         },
#         "terminal": "1",
#         "baggageBelt": "09",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "number": "6E 613",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "scheduledTime": {
#           "utc": "2026-06-14 13:35Z",
#           "local": "2026-06-14 19:05+05:30"
#         },
# ...
#           "local": "2026-06-14 21:00+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 15:51Z",
#           "local": "2026-06-14 21:21+05:30"
#         },
#         "terminal": "1",
#         "gate": "24",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 17:35Z",
#           "local": "2026-06-14 23:05+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 5291",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VAID",
#           "iata": "IDR",
#           "name": "Indore",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 15:40Z",
#           "local": "2026-06-14 21:10+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 17:40Z",
#           "local": "2026-06-14 23:10+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 756",
#       "callSign": "IGO756",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-IXE",
#         "modeS": "8016A5",
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VOMD",
#           "iata": "IXM",
#           "name": "Madurai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 16:15Z",
#           "local": "2026-06-14 21:45+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 17:40Z",
#           "local": "2026-06-14 23:10+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 7253",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "ATR 72"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VIDP",
#           "iata": "DEL",
#           "name": "New Delhi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 15:00Z",
#           "local": "2026-06-14 20:30+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 15:00Z",
#           "local": "2026-06-14 20:30+05:30"
#         },
#         "terminal": "1",
#         "gate": "D22",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 17:50Z",
#           "local": "2026-06-14 23:20+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6341",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VECC",
#           "iata": "CCU",
#           "name": "Kolkata",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 15:45Z",
#           "local": "2026-06-14 21:15+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:00Z",
#           "local": "2026-06-14 23:30+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 723",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VHHH",
#           "iata": "HKG",
#           "name": "Hong Kong",
#           "countryCode": "hk",
#           "timeZone": "Asia/Hong_Kong"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 12:35Z",
#           "local": "2026-06-14 20:35+08:00"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 12:35Z",
#           "local": "2026-06-14 20:35+08:00"
#         },
#         "terminal": "1",
#         "checkInDesk": "B,C",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:05Z",
#           "local": "2026-06-14 23:35+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "CX 651",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A330-300"
#       },
#       "airline": {
#         "name": "Cathay Pacific",
#         "iata": "CX",
#         "icao": "CPA"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VTBS",
#           "iata": "BKK",
#           "name": "Bangkok",
#           "countryCode": "th",
#           "timeZone": "Asia/Bangkok"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:55Z",
#           "local": "2026-06-14 21:55+07:00"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:15Z",
#           "local": "2026-06-14 23:45+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "TG 337",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A330-300"
#       },
#       "airline": {
#         "name": "Thai  International",
#         "iata": "TG",
#         "icao": "THA"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VOHS",
#           "iata": "HYD",
#           "name": "Hyderabad",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 16:55Z",
#           "local": "2026-06-14 22:25+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:20Z",
#           "local": "2026-06-14 23:50+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6617",
#       "status": "Expected",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "WSSS",
#           "iata": "SIN",
#           "name": "Singapore",
#           "countryCode": "sg",
#           "timeZone": "Asia/Singapore"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 14:20Z",
#           "local": "2026-06-14 22:20+08:00"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 14:20Z",
#           "local": "2026-06-14 22:20+08:00"
#         },
#         "terminal": "2",
#         "checkInDesk": "2",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:25Z",
#           "local": "2026-06-14 23:55+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 1004",
#       "callSign": "IGO1004",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "VT-ICH",
#         "modeS": "801744",
#         "model": "Airbus A321 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "EDDF",
#           "iata": "FRA",
#           "name": "Frankfurt-am-Main",
#           "countryCode": "de",
#           "timeZone": "Europe/Berlin"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 09:10Z",
#           "local": "2026-06-14 11:10+02:00"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 09:10Z",
#           "local": "2026-06-14 11:10+02:00"
#         },
#         "runwayTime": {
#           "utc": "2026-06-14 09:36Z",
#           "local": "2026-06-14 11:36+02:00"
#         },
#         "terminal": "1",
#         "checkInDesk": "259-335",
#         "gate": "Z16",
#         "runway": "18",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:40Z",
#           "local": "2026-06-15 00:10+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "LH 758",
#       "callSign": "DLH758",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "reg": "D-AIGP",
#         "modeS": "3C64F0",
#         "model": "Airbus A340"
#       },
#       "airline": {
#         "name": "Lufthansa",
#         "iata": "LH",
#         "icao": "DLH"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VAAH",
#           "iata": "AMD",
#           "name": "Ahmedabad",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 16:15Z",
#           "local": "2026-06-14 21:45+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 18:45Z",
#           "local": "2026-06-15 00:15+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 348",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VAPO",
#           "iata": "PNQ",
#           "name": "Pune",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 17:15Z",
#           "local": "2026-06-14 22:45+05:30"
#         },
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 19:05Z",
#           "local": "2026-06-15 00:35+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 238",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VIDP",
#           "iata": "DEL",
#           "name": "New Delhi",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 16:25Z",
#           "local": "2026-06-14 21:55+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 16:25Z",
#           "local": "2026-06-14 21:55+05:30"
#         },
#         "terminal": "3",
#         "gate": "51",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 19:15Z",
#           "local": "2026-06-15 00:45+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "AI 2895",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320 NEO"
#       },
#       "airline": {
#         "name": "Air India",
#         "iata": "AI",
#         "icao": "AIC"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 17:30Z",
#           "local": "2026-06-14 23:00+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 17:42Z",
#           "local": "2026-06-14 23:12+05:30"
#         },
#         "terminal": "2",
#         "gate": "47A",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 19:35Z",
#           "local": "2026-06-15 01:05+05:30"
#         },
#         "terminal": "1",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "6E 6137",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A320"
#       },
#       "airline": {
#         "name": "IndiGo",
#         "iata": "6E",
#         "icao": "IGO"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "VABB",
#           "iata": "BOM",
#           "name": "Mumbai",
#           "countryCode": "in",
#           "timeZone": "Asia/Kolkata"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 17:25Z",
#           "local": "2026-06-14 22:55+05:30"
#         },
#         "revisedTime": {
#           "utc": "2026-06-14 17:29Z",
#           "local": "2026-06-14 22:59+05:30"
#         },
#         "terminal": "2",
#         "gate": "41A",
#         "quality": [
#           "Basic",
#           "Live"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 19:35Z",
#           "local": "2026-06-15 01:05+05:30"
#         },
#         "terminal": "4",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "AI 639",
#       "status": "Expected",
#       "codeshareStatus": "IsOperator",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Airbus A321"
#       },
#       "airline": {
#         "name": "Air India",
#         "iata": "AI",
#         "icao": "AIC"
#       }
#     },
#     {
#       "departure": {
#         "airport": {
#           "icao": "HAAB",
#           "iata": "ADD",
#           "name": "Addis Ababa",
#           "countryCode": "et",
#           "timeZone": "Africa/Addis_Ababa"
#         },
#         "scheduledTime": {
#           "utc": "2026-06-14 13:00Z",
#           "local": "2026-06-14 16:00+03:00"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "arrival": {
#         "scheduledTime": {
#           "utc": "2026-06-14 19:40Z",
#           "local": "2026-06-15 01:10+05:30"
#         },
#         "terminal": "2",
#         "quality": [
#           "Basic"
#         ]
#       },
#       "number": "ET 696",
#       "status": "Expected",
#       "codeshareStatus": "Unknown",
#       "isCargo": false,
#       "aircraft": {
#         "model": "Boeing 737"
#       },
#       "airline": {
#         "name": "Ethiopian",
#         "iata": "ET",
#         "icao": "ETH"
#       }
#     }
#   ]
# }

# %%
# Fetch and insert flights for all airports
def insert_flights(flights_list, airport_iata):
    conn = get_connection()
    cursor = conn.cursor()
    inserted = 0
    
    for flight in flights_list:
        try:
            cursor.execute("""
                INSERT INTO flights 
                (flight_id, flight_number, aircraft_model, aircraft_registration,
                origin_iata, destination_iata,
                scheduled_departure, actual_departure, scheduled_arrival, actual_arrival,
                status, airline_code)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                ON CONFLICT (flight_id) DO NOTHING
            """, (
                flight.get("number"),
                flight.get("number"),
                flight.get("aircraft", {}).get("model"),
                flight.get("aircraft", {}).get("reg"),
                flight.get("departure", {}).get("airport", {}).get("iata", airport_iata),
                flight.get("arrival", {}).get("airport", {}).get("iata"),
                flight.get("departure", {}).get("scheduledTime", {}).get("local"),
                flight.get("departure", {}).get("actualTime", {}).get("local"),
                flight.get("arrival", {}).get("scheduledTime", {}).get("local"),
                flight.get("arrival", {}).get("actualTime", {}).get("local"),
                flight.get("status"),
                flight.get("airline", {}).get("iata")
            ))
            inserted += 1
        except Exception as e:
            print(f"Error inserting flight {flight.get('number')}: {e}")
    
    conn.commit()
    cursor.close()
    conn.close()
    return inserted

# Fetch flights for all 15 airports
yesterday = (datetime.now() - timedelta(days=1)).strftime("%Y-%m-%d")
total_flights = 0

for code in AIRPORT_CODES:
    print(f"Fetching flights for {code}...")
    data = fetch_flights(code, yesterday)
    if data:
        flights_list = []
        if "departures" in data:
            flights_list += data["departures"]
        if "arrivals" in data:
            flights_list += data["arrivals"]
        count = insert_flights(flights_list, code)
        total_flights += count
        print(f"  → Inserted {count} flights")
    time.sleep(2)

print(f"\nTotal flights inserted: {total_flights}")
# Out:
# Fetching flights for DXB...
# Error fetching flights for DXB: 429 Client Error: Too Many Requests for url: https://aerodatabox.p.rapidapi.com/flights/airports/iata/DXB?fromLocal=2026-06-13T00%3A00&toLocal=2026-06-13T23%3A59&withLeg=true&direction=Both&withCancelled=true&withCodeshared=false&withCargo=false&withPrivate=false
# Fetching flights for SIN...
#   → Inserted 491 flights
# Fetching flights for LHR...
#   → Inserted 998 flights
# Fetching flights for JFK...
#   → Inserted 663 flights
# Fetching flights for SYD...
#   → Inserted 204 flights
# Fetching flights for DOH...
#   → Inserted 206 flights
# Fetching flights for BKK...
#   → Inserted 518 flights
# Fetching flights for CDG...
#   → Inserted 980 flights
# Fetching flights for MAA...
#   → Inserted 207 flights
# Fetching flights for DEL...
#   → Inserted 710 flights
# Fetching flights for BOM...
#   → Inserted 446 flights
# Fetching flights for BLR...
#   → Inserted 418 flights
# Fetching flights for HYD...
#   → Inserted 265 flights
# Fetching flights for CCU...
#   → Inserted 188 flights
# Fetching flights for COK...
#   → Inserted 82 flights
#
# Total flights inserted: 6376

# %%
# Aircraft detail functions
# Per the project spec: take the unique aircraft registrations seen in the
# flights table and fetch each aircraft's detail from the aircrafts API.
def fetch_aircraft(registration):
    url = f"https://{API_HOST}/aircrafts/reg/{registration}"
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error fetching aircraft {registration}: {e}")
        return None

def insert_aircraft(record):
    """Insert a single aircraft detail record. Returns 1 if inserted, else 0."""
    conn = get_connection()
    cursor = conn.cursor()
    inserted = 0
    try:
        type_name = record.get("typeName") or record.get("model")
        manufacturer = type_name.split()[0] if type_name else None
        cursor.execute("""
            INSERT INTO aircraft (registration, model, manufacturer, icao_type_code, owner)
            VALUES (%s, %s, %s, %s, %s)
            ON CONFLICT (registration) DO NOTHING
        """, (
            record.get("reg") or record.get("registration"),
            record.get("model") or record.get("typeName"),
            manufacturer,
            record.get("icaoCode") or record.get("typeCode"),
            record.get("airlineName") or record.get("owner"),
        ))
        conn.commit()
        inserted = cursor.rowcount
    except Exception as e:
        print(f"Error inserting aircraft {record.get('reg')}: {e}")
    cursor.close()
    conn.close()
    return inserted

# Quick test on a single registration from the flights table
def get_unique_registrations(limit=40):
    conn = get_connection()
    cursor = conn.cursor()
    cursor.execute("""
        SELECT DISTINCT aircraft_registration
        FROM flights
        WHERE aircraft_registration IS NOT NULL
        LIMIT %s
    """, (limit,))
    regs = [row[0] for row in cursor.fetchall()]
    cursor.close()
    conn.close()
    return regs

sample = get_unique_registrations(limit=1)
if sample:
    print(f"Testing aircraft fetch for {sample[0]}...")
    print(json.dumps(fetch_aircraft(sample[0]), indent=2))
else:
    print("No registrations in flights table yet — run the flights cell first.")
# Out:
# Testing aircraft fetch for 9V-SMG...
# {
#   "id": 2116546,
#   "reg": "9V-SMG",
#   "active": true,
#   "serial": "62",
#   "hexIcao": "76CDA7",
#   "airlineName": "Singapore Airlines",
#   "iataCodeShort": "359",
#   "icaoCode": "A359",
#   "model": "A359",
#   "modelCode": "350-941",
#   "numSeats": 253,
#   "rolloutDate": "2016-11-17",
#   "registrationDate": "2016-12-06",
#   "typeName": "Airbus A350-900",
#   "numEngines": 2,
#   "engineType": "Jet",
#   "isFreighter": false,
#   "productionLine": "Airbus A350",
#   "ageYears": 9.6,
#   "verified": true,
#   "numRegistrations": 1
# }

# %%
# Fetch and insert details for every unique aircraft registration in the flights table
registrations = get_unique_registrations(limit=40)
print(f"Found {len(registrations)} unique registrations to fetch\n")

total_aircraft = 0
for reg in registrations:
    print(f"Fetching aircraft {reg}...")
    data = fetch_aircraft(reg)
    if data:
        count = insert_aircraft(data)
        total_aircraft += count
        print(f"  → Inserted {count} aircraft")
    time.sleep(2)

print(f"\nTotal aircraft inserted: {total_aircraft}")
# Out:
# Found 40 unique registrations to fetch
#
# Fetching aircraft 9V-SMG...
# Error fetching aircraft 9V-SMG: 429 Client Error: Too Many Requests for url: https://aerodatabox.p.rapidapi.com/aircrafts/reg/9V-SMG
# Fetching aircraft N663JB...
#   → Inserted 1 aircraft
# Fetching aircraft 9K-APJ...
#   → Inserted 1 aircraft
# Fetching aircraft N912XJ...
#   → Inserted 1 aircraft
# Fetching aircraft D-AIXH...
#   → Inserted 1 aircraft
# Fetching aircraft VT-SLG...
#   → Inserted 1 aircraft
# Fetching aircraft A6-EGI...
#   → Inserted 1 aircraft
# Fetching aircraft B-9932...
#   → Inserted 1 aircraft
# Fetching aircraft VT-GSK...
#   → Inserted 1 aircraft
# Fetching aircraft N667UA...
#   → Inserted 1 aircraft
# Fetching aircraft 9V-TNI...
#   → Inserted 1 aircraft
# Fetching aircraft 4X-ECD...
#   → Inserted 1 aircraft
# Fetching aircraft PH-NXZ...
#   → Inserted 1 aircraft
# Fetching aircraft N827SK...
#   → Inserted 1 aircraft
# Fetching aircraft F-HUVJ...
#   → Inserted 1 aircraft
# Fetching aircraft 9H-NEC...
#   → Inserted 1 aircraft
# Fetching aircraft A6-LRF...
#   → Inserted 1 aircraft
# Fetching aircraft VT-BXM...
#   → Inserted 1 aircraft
# Fetching aircraft VT-IQP...
#   → Inserted 1 aircraft
# Fetching aircraft D-ANRT...
#   → Inserted 1 aircraft
# Fetching aircraft G-ZBLF...
#   → Inserted 1 aircraft
# Fetching aircraft N593JB...
#   → Inserted 1 aircraft
# Fetching aircraft VT-PPH...
#   → Inserted 1 aircraft
# Fetching aircraft N173DZ...
#   → Inserted 1 aircraft
# Fetching aircraft VT-NHC...
# Error fetching aircraft VT-NHC: Expecting value: line 1 column 1 (char 0)
# Fetching aircraft VT-IME...
#   → Inserted 1 aircraft
# Fetching aircraft HL8502...
# Error fetching aircraft HL8502: Expecting value: line 1 column 1 (char 0)
# Fetching aircraft G-TTNS...
#   → Inserted 1 aircraft
# Fetching aircraft N712TW...
#   → Inserted 1 aircraft
# Fetching aircraft G-TNEG...
#   → Inserted 0 aircraft
# Fetching aircraft XU-787...
#   → Inserted 1 aircraft
# Fetching aircraft N643JB...
#   → Inserted 1 aircraft
# Fetching aircraft 9V-DHB...
#   → Inserted 1 aircraft
# Fetching aircraft VH-YQM...
#   → Inserted 1 aircraft
# Fetching aircraft A6-LRG...
#   → Inserted 1 aircraft
# Fetching aircraft HS-TXN...
#   → Inserted 1 aircraft
# Fetching aircraft F-HBQA...
#   → Inserted 1 aircraft
# Fetching aircraft HP-1840...
#   → Inserted 1 aircraft
# Fetching aircraft N188DN...
#   → Inserted 1 aircraft
# Fetching aircraft HZ-AK36...
#   → Inserted 1 aircraft
#
# Total aircraft inserted: 36

# %%
# Test airport delays with ICAO code
def fetch_airport_delays(icao_code):
    url = f"https://{API_HOST}/airports/icao/{icao_code}/delays"
    try:
        response = requests.get(url, headers=HEADERS)
        response.raise_for_status()
        return response.json()
    except Exception as e:
        print(f"Error fetching delays for {icao_code}: {e}")
        return None

# Test with MAA (ICAO: VOMM)
test_delays = fetch_airport_delays("VOMM")
print(json.dumps(test_delays, indent=2))
# Out:
# Error fetching delays for VOMM: 400 Client Error: Bad Request for url: https://aerodatabox.p.rapidapi.com/airports/icao/VOMM/delays
# null

# %%
# Airport ICAO to IATA mapping
AIRPORT_ICAO = {
    "DXB": "OMDB", "SIN": "WSSS", "LHR": "EGLL", "JFK": "KJFK",
    "SYD": "YSSY", "DOH": "OTHH", "BKK": "VTBS", "CDG": "LFPG",
    "MAA": "VOMM", "DEL": "VIDP", "BOM": "VABB", "BLR": "VOBL",
    "HYD": "VOHS", "CCU": "VECC", "COK": "VOCI"
}

def insert_delays(iata_code, data):
    conn = get_connection()
    cursor = conn.cursor()
    try:
        total = (data.get("departuresDelayInformation", {}).get("numTotal", 0) +
                 data.get("arrivalsDelayInformation", {}).get("numTotal", 0))
        delayed = (data.get("departuresDelayInformation", {}).get("numQualifiedTotal", 0) +
                   data.get("arrivalsDelayInformation", {}).get("numQualifiedTotal", 0))
        cancelled = (data.get("departuresDelayInformation", {}).get("numCancelled", 0) +
                     data.get("arrivalsDelayInformation", {}).get("numCancelled", 0))
        cursor.execute("""
            INSERT INTO airport_delays 
            (airport_iata, delay_date, total_flights, delayed_flights, avg_delay_min, median_delay_min, canceled_flights)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
        """, (
            iata_code,
            data.get("from", {}).get("utc"),
            total,
            delayed,
            0,
            0,
            cancelled
        ))
        conn.commit()
        print(f"  → Inserted delays for {iata_code}")
    except Exception as e:
        print(f"Error inserting delays for {iata_code}: {e}")
    cursor.close()
    conn.close()

# Fetch delays for all 15 airports
for iata, icao in AIRPORT_ICAO.items():
    print(f"Fetching delays for {iata}...")
    data = fetch_airport_delays(icao)
    if data:
        insert_delays(iata, data)
    time.sleep(2)

print("\nAll delays inserted!")
# Out:
# Fetching delays for DXB...
# Error fetching delays for OMDB: 429 Client Error: Too Many Requests for url: https://aerodatabox.p.rapidapi.com/airports/icao/OMDB/delays
# Fetching delays for SIN...
#   → Inserted delays for SIN
# Fetching delays for LHR...
#   → Inserted delays for LHR
# Fetching delays for JFK...
#   → Inserted delays for JFK
# Fetching delays for SYD...
#   → Inserted delays for SYD
# Fetching delays for DOH...
#   → Inserted delays for DOH
# Fetching delays for BKK...
#   → Inserted delays for BKK
# Fetching delays for CDG...
#   → Inserted delays for CDG
# Fetching delays for MAA...
# Error fetching delays for VOMM: 400 Client Error: Bad Request for url: https://aerodatabox.p.rapidapi.com/airports/icao/VOMM/delays
# Fetching delays for DEL...
#   → Inserted delays for DEL
# Fetching delays for BOM...
#   → Inserted delays for BOM
# Fetching delays for BLR...
#   → Inserted delays for BLR
# Fetching delays for HYD...
#   → Inserted delays for HYD
